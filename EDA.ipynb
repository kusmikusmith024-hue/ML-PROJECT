# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("iris")
print(df.head(10))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
print(df.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print("Shape:",df.shape)
# Out:
# Shape: (150, 5)

# %%
print("Columns:",df.columns.tolist())
# Out:
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
print(df.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print("Total missing values:",df.isnull())
# Out:
# Total missing values:      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
print("Total missing values:",df.isnull().sum())
# Out:
# Total missing values: sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("Total missing values:",df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Total number of rows:",len(df))
# Out:
# Total number of rows: 150

# %%
print("Total number of columns:",df.shape[1])
# Out:
# Total number of columns: 5

# %%
print(df["species"].value_counts())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print(df["species"].value_counts(normalize=True)*100)
# Out:
# species
# setosa        33.333333
# versicolor    33.333333
# virginica     33.333333
# Name: proportion, dtype: float64

# %%
print("Species of:",df["species"].unique())
# Out:
# Species of: ['setosa' 'versicolor' 'virginica']

# %%
print("Number of unique species:",df["species"].nunique())
# Out:
# Number of unique species: 3

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df.select_dtypes("number").mean())
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
print(df.select_dtypes("number").median())
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
print(df.select_dtypes("number").var())
# Out:
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64

# %%
print(df.select_dtypes("number").max())
# Out:
# sepal_length    7.9
# sepal_width     4.4
# petal_length    6.9
# petal_width     2.5
# dtype: float64

# %%
print(df.select_dtypes("number").min())
# Out:
# sepal_length    4.3
# sepal_width     2.0
# petal_length    1.0
# petal_width     0.1
# dtype: float64

# %%
print(df.select_dtypes("number").std())
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
print(df.select_dtypes("number").mode())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.0          3.0           1.4          0.2
# 1           NaN          NaN           1.5          NaN

# %%
sns.countplot(data=df,x="species")
plt.title("Number of flowers by species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(data=df,x="sepal_length",bins=7,kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(data=df,x="species",y="petal_length")
plt.title("Petal length by species")
plt.show()
